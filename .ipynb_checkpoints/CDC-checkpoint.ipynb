# %%
import pandas as pd

# %%
data = pd.read_csv('CDC_CLEANED.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-ab06581e259a> in <module>
# ----> 1 data = pd.read_csv('CDC_CLEANED.csv')
#
# C:\Python\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# C:\Python\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# C:\Python\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\Python\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# C:\Python\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'CDC_CLEANED.csv' does not exist: b'CDC_CLEANED.csv'

# %%
data.head()
# Out:
#    census_tract conforming_loan_limit derived_loan_product_type  \
# 0  3.711901e+10                     C   Conventional:First Lien
# 1  3.711901e+10                     C   Conventional:First Lien
# 2  3.708507e+10                     C   Conventional:First Lien
# 3  3.706502e+10                     C   Conventional:First Lien
# 4  3.718595e+10                     C   Conventional:First Lien
#
#         derived_ethnicity        derived_race derived_sex  action_taken  \
# 0      Hispanic or Latino  Race Not Available       Joint             2
# 1      Hispanic or Latino  Race Not Available       Joint             2
# 2      Hispanic or Latino  Race Not Available        Male             3
# 3  Not Hispanic or Latino               White        Male             4
# 4  Not Hispanic or Latino               White       Joint             1
#
#    purchaser_type  preapproval  loan_type  ...  total_units  income  \
# 0               0            2          1  ...            1    51.0
# 1               0            2          1  ...            1    51.0
# 2               0            2          1  ...            1    36.0
# 3               0            2          1  ...            1    39.0
# 4               8            2          1  ...            1    92.0
#
#    debt_to_income_ratio applicant_age denial_reason-1 tract_population  \
# 0              20%-<30%         55-64              10             7063
# 1              20%-<30%         55-64              10             7063
# 2              20%-<30%         55-64               7             4746
# 3                   NaN         25-34              10             3162
# 4                    38         45-54              10             4162
#
#    tract_minority_population_percent  ffiec_msa_md_median_family_income  \
# 0                              68.84                              70700
# 1                              68.84                              70700
# 2                              46.46                              56500
# 3                              47.53                              54700
# 4                              69.46                              51600
#
#    tract_to_msa_income_percentage tract_median_age_of_housing_units
# 0                              84                                15
# 1                              84                                15
# 2                              73                                44
# 3                              79                                38
# 4                              74                                40
#
# [5 rows x 27 columns]

# %%
data.dropna(inplace = True, thresh = 250000, axis = 1)

# %%
data.shape
# Out:
# (594769, 43)

# %%
data.columns
# Out:
# Index(['county_code', 'census_tract', 'conforming_loan_limit',
#        'derived_loan_product_type', 'derived_ethnicity', 'derived_race',
#        'derived_sex', 'action_taken', 'purchaser_type', 'preapproval',
#        'loan_type', 'loan_purpose', 'open-end_line_of_credit',
#        'business_or_commercial_purpose', 'loan_amount', 'loan_to_value_ratio',
#        'interest_rate', 'rate_spread', 'total_loan_costs',
#        'origination_charges', 'loan_term', 'interest_only_payment',
#        'property_value', 'occupancy_type', 'total_units', 'income',
#        'debt_to_income_ratio', 'co-applicant_credit_score_type',
#        'applicant_ethnicity-1', 'co-applicant_ethnicity-1', 'applicant_race-1',
#        'co-applicant_race-1', 'applicant_age', 'co-applicant_age',
#        'applicant_age_above_62', 'denial_reason-1', 'tract_population',
#        'tract_minority_population_percent',
#        'ffiec_msa_md_median_family_income', 'tract_to_msa_income_percentage',
#        'tract_owner_occupied_units', 'tract_one_to_four_family_homes',
#        'tract_median_age_of_housing_units'],
#       dtype='object')

# %%
data.drop(['open-end_line_of_credit', 'rate_spread', 'total_loan_costs', 'origination_charges',
        'loan_term', 'interest_only_payment',
       'co-applicant_credit_score_type',
       'applicant_ethnicity-1', 'co-applicant_ethnicity-1', 'applicant_race-1',
       'co-applicant_race-1', 'co-applicant_age','applicant_age_above_62'], inplace = True, axis =1)

# %%
data.head()
# Out:
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0      37119.0  3.711901e+10                     C   Conventional:First Lien
# 1      37119.0  3.711901e+10                     C   Conventional:First Lien
# 2      37085.0  3.708507e+10                     C   Conventional:First Lien
# 3      37065.0  3.706502e+10                     C   Conventional:First Lien
# 4      37185.0  3.718595e+10                     C   Conventional:First Lien
#
#         derived_ethnicity        derived_race derived_sex  action_taken  \
# 0      Hispanic or Latino  Race Not Available       Joint             2
# 1      Hispanic or Latino  Race Not Available       Joint             2
# 2      Hispanic or Latino  Race Not Available        Male             3
# 3  Not Hispanic or Latino               White        Male             4
# 4  Not Hispanic or Latino               White       Joint             1
#
#    purchaser_type  preapproval  ...  debt_to_income_ratio  applicant_age  \
# 0               0            2  ...              20%-<30%          55-64
# 1               0            2  ...              20%-<30%          55-64
# 2               0            2  ...              20%-<30%          55-64
# 3               0            2  ...                   NaN          25-34
# 4               8            2  ...                    38          45-54
#
#    denial_reason-1  tract_population tract_minority_population_percent  \
# 0               10              7063                             68.84
# 1               10              7063                             68.84
# 2                7              4746                             46.46
# 3               10              3162                             47.53
# 4               10              4162                             69.46
#
#   ffiec_msa_md_median_family_income tract_to_msa_income_percentage  \
# 0                             70700                             84
# 1                             70700                             84
# 2                             56500                             73
# 3                             54700                             79
# 4                             51600                             74
#
#    tract_owner_occupied_units  tract_one_to_four_family_homes  \
# 0                        2053                            2733
# 1                        2053                            2733
# 2                        1068                            1969
# 3                         761                            1416
# 4                         920                            1872
#
#    tract_median_age_of_housing_units
# 0                                 15
# 1                                 15
# 2                                 44
# 3                                 38
# 4                                 40
#
# [5 rows x 30 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.dtypes
# Out:
# county_code                          float64
# census_tract                         float64
# conforming_loan_limit                 object
# derived_loan_product_type             object
# derived_ethnicity                     object
# derived_race                          object
# derived_sex                           object
# action_taken                           int64
# purchaser_type                         int64
# preapproval                            int64
# loan_type                              int64
# loan_purpose                           int64
# business_or_commercial_purpose         int64
# loan_amount                          float64
# loan_to_value_ratio                   object
# interest_rate                         object
# property_value                        object
# occupancy_type                         int64
# total_units                            int64
# income                               float64
# debt_to_income_ratio                  object
# applicant_age                         object
# denial_reason-1                        int64
# tract_population                       int64
# tract_minority_population_percent    float64
# ffiec_msa_md_median_family_income      int64
# tract_to_msa_income_percentage         int64
# tract_owner_occupied_units             int64
# tract_one_to_four_family_homes         int64
# tract_median_age_of_housing_units      int64
# dtype: object

# %%
data.drop(['tract_owner_occupied_units', 'tract_one_to_four_family_homes', 'county_code']
          , axis =1, inplace = True)

# %%
data.head()
# Out:
#    census_tract conforming_loan_limit derived_loan_product_type  \
# 0  3.711901e+10                     C   Conventional:First Lien
# 1  3.711901e+10                     C   Conventional:First Lien
# 2  3.708507e+10                     C   Conventional:First Lien
# 3  3.706502e+10                     C   Conventional:First Lien
# 4  3.718595e+10                     C   Conventional:First Lien
#
#         derived_ethnicity        derived_race derived_sex  action_taken  \
# 0      Hispanic or Latino  Race Not Available       Joint             2
# 1      Hispanic or Latino  Race Not Available       Joint             2
# 2      Hispanic or Latino  Race Not Available        Male             3
# 3  Not Hispanic or Latino               White        Male             4
# 4  Not Hispanic or Latino               White       Joint             1
#
#    purchaser_type  preapproval  loan_type  ...  total_units  income  \
# 0               0            2          1  ...            1    51.0
# 1               0            2          1  ...            1    51.0
# 2               0            2          1  ...            1    36.0
# 3               0            2          1  ...            1    39.0
# 4               8            2          1  ...            1    92.0
#
#    debt_to_income_ratio applicant_age denial_reason-1 tract_population  \
# 0              20%-<30%         55-64              10             7063
# 1              20%-<30%         55-64              10             7063
# 2              20%-<30%         55-64               7             4746
# 3                   NaN         25-34              10             3162
# 4                    38         45-54              10             4162
#
#    tract_minority_population_percent  ffiec_msa_md_median_family_income  \
# 0                              68.84                              70700
# 1                              68.84                              70700
# 2                              46.46                              56500
# 3                              47.53                              54700
# 4                              69.46                              51600
#
#    tract_to_msa_income_percentage tract_median_age_of_housing_units
# 0                              84                                15
# 1                              84                                15
# 2                              73                                44
# 3                              79                                38
# 4                              74                                40
#
# [5 rows x 27 columns]
